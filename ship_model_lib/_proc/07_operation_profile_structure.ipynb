# %% [raw]
# ---
# description: Fill in a module description here
# output-file: operation_profile_structure.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(OperationPoint)
# Out:
# ---
#
# ### OperationPoint
#
# >      OperationPoint (speed_kn:Union[float,numpy.ndarray],
# >                      timestamp_seconds:Union[float,numpy.ndarray]=None,
# >                      power_limit_kw:Union[float,numpy.ndarray]=1000000.0,
# >                      heading_deg:Union[float,numpy.ndarray]=None,
# >                      auxiliary_power:Union[float,numpy.ndarray]=0,
# >                      weather:__main__.Weather=None,
# >                      location:__main__.Location=None)
#
# *Operation point class*

# %%
#| echo: false
#| output: asis
show_doc(Weather)
# Out:
# ---
#
# ### Weather
#
# >      Weather (significant_wave_height_m:Union[float,numpy.ndarray]=None,
# >               mean_wave_period_s:Union[float,numpy.ndarray]=None,
# >               wave_direction_deg:Union[float,numpy.ndarray]=None,
# >               wind_speed_m_per_s:Union[float,numpy.ndarray]=None,
# >               wind_direction_deg:Union[float,numpy.ndarray]=None,
# >               ocean_current_speed_m_per_s:Union[float,numpy.ndarray]=None,
# >               ocean_current_direction_deg:Union[float,numpy.ndarray]=None,
# >               air_temperature_deg_c:Union[float,numpy.ndarray]=None,
# >               sea_water_temperature_deg_c:Union[float,numpy.ndarray]=None)
#
# *Wrapper class for the weather*

# %%
#| echo: false
#| output: asis
show_doc(Location)
# Out:
# ---
#
# ### Location
#
# >      Location (longitude:Union[float,numpy.ndarray,NoneType]=None,
# >                latitude:Union[float,numpy.ndarray,NoneType]=None)
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %%
from random import random

data = dict(
    significant_wave_height_m=random(),
    mean_wave_period_s=random(),
    wave_direction_deg=random(),
    wind_direction_deg=random(),
    wind_speed_m_per_s=random(),
    ocean_current_direction_deg=random(),
    ocean_current_speed_m_per_s=random(),
    sea_water_temperature_deg_c=random(),
    air_temperature_deg_c=random(),
)

weather = Weather(**data)
for key, value in data.items():
    assert getattr(weather, key) == value

# %%
operation_point = OperationPoint(
    timestamp_seconds=123,
    speed_kn=5.6,
    power_limit_kw=10000,
    heading_deg=34,
    auxiliary_power=4.6,
    weather=weather,
    location=Location(longitude=5.6, latitude=4.2),
)

# %%
print(operation_point.weather.to_dict())
print(operation_point.location.to_dict())
# Out:
# {'significant_wave_height_m': array([0.59208887]), 'mean_wave_period_s': array([0.3524404]), 'wave_direction_deg': array([0.55018842]), 'wind_speed_m_per_s': array([0.54849195]), 'wind_direction_deg': array([0.34128116]), 'ocean_current_speed_m_per_s': array([0.35256215]), 'ocean_current_direction_deg': array([0.83863329]), 'air_temperature_deg_c': array([0.61077008]), 'sea_water_temperature_deg_c': array([0.02546532])}
# {'longitude': array([5.6]), 'latitude': array([4.2])}

# %%
operation_point.to_dict_scalar()
# Out:
# {'timestamp_seconds': 123,
#  'speed_kn': 5.6,
#  'power_limit_kw': 10000,
#  'heading_deg': 34,
#  'auxiliary_power': 4.6,
#  'weather': {'significant_wave_height_m': 0.5920888696450309,
#   'mean_wave_period_s': 0.3524403973696101,
#   'wave_direction_deg': 0.5501884249156584,
#   'wind_speed_m_per_s': 0.548491946151775,
#   'wind_direction_deg': 0.34128116225185534,
#   'ocean_current_speed_m_per_s': 0.3525621471381386,
#   'ocean_current_direction_deg': 0.8386332885584238,
#   'air_temperature_deg_c': 0.6107700836198648,
#   'sea_water_temperature_deg_c': 0.025465316709767927},
#  'location': {'longitude': 5.6, 'latitude': 4.2}}
